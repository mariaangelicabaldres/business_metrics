# %% [markdown]
# # GENERATE QUARTERLY REPORT

# %% [markdown]
# ### Section 1: Setup and Imports

# %%
# =============================================================================
# SECTION 1: SETUP AND IMPORTS
# =============================================================================
# This section imports all required libraries for:
# - Document creation (python-docx)
# - Data processing (pandas, numpy)
# - File operations (os, datetime)
# - Statistical analysis (scipy)

import pandas as pd
import numpy as np
from docx import Document
from docx.shared import Inches, Pt, Cm, RGBColor
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.enum.table import WD_TABLE_ALIGNMENT
from docx.enum.style import WD_STYLE_TYPE
from docx.oxml.ns import qn, nsdecls
from docx.oxml import parse_xml, OxmlElement
import os
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Import scipy for trend analysis
try:
    from scipy import stats
except ImportError:
    import subprocess
    subprocess.check_call(['pip', 'install', 'scipy', '--break-system-packages', '-q'])
    from scipy import stats

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %% [markdown]
# ### Section 2: Configuration and Path Setup

# %%
# =============================================================================
# SECTION 2: CONFIGURATION AND PATH SETUP
# =============================================================================
# Define all paths and configuration settings for Quarterly Business Review
# Key differences from MBR:
# - Uses 6-quarter average instead of 6-month
# - Uses QoQ (Quarter-over-Quarter) instead of MoM (Month-over-Month)
# - Trend periods: 4, 8, 12 quarters instead of 6, 12, 24 months
# - 4 quarters = 1 year, so 4-quarter trend = 1-year trend

# Base path configuration - assumes notebook is in 'notebooks' folder
BASE_PATH = os.path.dirname(os.getcwd())

# Folder paths
OUTPUTS_PATH = os.path.join(BASE_PATH, 'outputs')
VISUALIZATIONS_PATH = os.path.join(BASE_PATH, 'visualizations')
REPORTS_PATH = os.path.join(BASE_PATH, 'reports')
REF_DATE_FILE = os.path.join(BASE_PATH, 'analysis_ref_date.csv')
TARGET_FILE = os.path.join(BASE_PATH, 'target_reference.csv')  # Goal targets file

# Create reports folder if it doesn't exist
os.makedirs(REPORTS_PATH, exist_ok=True)

# Configuration settings for QBR
CONFIG = {
    # Analysis periods (in quarters for QBR)
    # 6-quarter average = 1.5 years of historical data
    'quarters_for_average': 6,
    'near_threshold_pct': 0.05,        # ±5% = "Near" the average (configurable)
    
    # Spike/Dip detection thresholds
    'spike_threshold_pct': 0.25,       # ±25% vs 6-quarter average (configurable)
    'spike_threshold_std': 2,          # ±2 standard deviations
    
    # Chart display settings
    'chart_width_inches': 4.0,         # Chart width in document
    'charts_per_page': 2,              # Target charts per page
    
    # Trend analysis periods (in quarters)
    # 4 quarters = 1 full year
    # 8 quarters = 2 years
    # 12 quarters = 3 years
    'trend_short_term': 4,             # 4-quarter trend (1 year)
    'trend_medium_term': 8,            # 8-quarter trend (2 years)
    'trend_long_term': 12,             # 12-quarter trend (3 years)
    
    # Minimum data points required for trend analysis
    'min_points_for_trend': 4,
}

# Metrics with INVERTED color logic (lower is better)
# For these metrics: going DOWN = favorable (green), going UP = unfavorable (red)
INVERTED_METRICS = [
    'Active Unsubs', 'Auto Unsubs', 'Unsubscribes', 'Unsubscribed',
    'Leak Rate', 'List Unsub Rate', 'Blended Unsub Rate', 'Unsubscribe Rate',
    'Bounce Rate', 'Deal Unsubscribe Rate', 'Off-Market Unsubscribe Rate',
    'Podcast Unsubscribe Rate', 'Case Study Unsubscribe Rate',
    'Avg Lead Time', 'Cancellation Rate'
]

# Metrics that should use absolute values (stored as negative in CSV)
ABSOLUTE_VALUE_METRICS = [
    'Unsubscribed', 'Unsubscribes'
]

print(f"✓ Configuration loaded")
print(f"  Chart width: {CONFIG['chart_width_inches']}\"")
print(f"  Inverted metrics: {len(INVERTED_METRICS)}")
print(f"  Trend periods: {CONFIG['trend_short_term']}, {CONFIG['trend_medium_term']}, {CONFIG['trend_long_term']} quarters")
print(f"  Target file: {os.path.basename(TARGET_FILE)}")
# Out:
# ✓ Configuration loaded
#   Chart width: 4.0"
#   Inverted metrics: 15
#   Trend periods: 4, 8, 12 quarters
#   Target file: target_reference.csv

# %% [markdown]
# ### Section 3: Chart and Data Source Mapping

# %%
# =============================================================================
# SECTION 3: CHART AND DATA SOURCE MAPPING
# =============================================================================
# This mapping connects each chart to:
# - 'image': path to PNG file (relative to visualizations folder)
# - 'csv': path to data CSV file (relative to outputs folder)
# - 'metric': column name in CSV containing the metric values
# - 'date_col': column(s) for date reference
# - 'goal_metric': metric name in target_reference.csv (None if no goal)
#
# NOTE: For QBR, we use quarterly chart folders (e.g., 'newsletter_quarterly')
# and quarterly data files (e.g., 'quarterly_newsletter.csv')

CHART_CONFIG = {
    # =========================================================================
    # NEWSLETTER METRICS - Landing Page Funnel (Pages 4-5)
    # =========================================================================
    'Newsletter Visits': {
        'image': 'newsletter_quarterly/quarterly_visits.png',
        'csv': 'newsletter/quarterly_newsletter.csv',
        'metric': 'Visits',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Newsletter Visits'
    },
    'Newsletter Visit Duration': {
        'image': 'newsletter_quarterly/quarterly_avg_duration.png',
        'csv': 'newsletter/quarterly_newsletter.csv',
        'metric': 'Avg Duration',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Newsletter Visit Duration'
    },
    'Newsletter Bounce Rate': {
        'image': 'newsletter_quarterly/quarterly_bounce_rate.png',
        'csv': 'newsletter/quarterly_newsletter.csv',
        'metric': 'Bounce Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Newsletter Bounce Rate'
    },
    'Newsletter CVR %': {
        'image': 'general_newsletter_quarterly/quarterly_newsletter_cvr.png',
        'csv': 'general_newsletter/quarterly_table.csv',
        'metric': 'Newsletter CVR %',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Newsletter CVR %'
    },
    
    # =========================================================================
    # NEWSLETTER METRICS - Engagement (Pages 6-7)
    # =========================================================================
    'Blended Open Rate': {
        'image': 'newsletter_series_quarterly/blended_open_rate.png',
        'csv': 'newsletter_series/09_blended_quarterly.csv',
        'metric': 'Open Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Blended Open Rate'
    },
    'Blended Verified Click-Through Rate': {
        'image': 'newsletter_series_quarterly/blended_verified_ctr.png',
        'csv': 'newsletter_series/09_blended_quarterly.csv',
        'metric': 'Verified Click-Through Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Blended Verified Click-Through Rate'
    },
    'Blended Unsub Rate': {
        'image': 'newsletter_series_quarterly/blended_unsubscribe_rate.png',
        'csv': 'newsletter_series/09_blended_quarterly.csv',
        'metric': 'Unsubscribe Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Blended Unsubscribe Rate'
    },
    
    # =========================================================================
    # NEWSLETTER METRICS - Growth & Churn (Pages 8-9)
    # =========================================================================
    'Growth Rate': {
        'image': 'general_newsletter_quarterly/quarterly_growth_rate.png',
        'csv': 'general_newsletter/quarterly_table.csv',
        'metric': 'Growth Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Growth Rate'
    },
    'New Subscribers': {
        'image': 'general_newsletter_quarterly/quarterly_subscribed.png',
        'csv': 'general_newsletter/quarterly_table.csv',
        'metric': 'Subscribed',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Subscribed'
    },
    'Unsubscribes': {
        'image': 'general_newsletter_quarterly/quarterly_unsubscribed.png',
        'csv': 'general_newsletter/quarterly_table.csv',
        'metric': 'Unsubscribed',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Unsubscribed'
    },
    'Leak Rate': {
        'image': 'general_newsletter_quarterly/quarterly_leak_rate.png',
        'csv': 'general_newsletter/quarterly_table.csv',
        'metric': 'Leak Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Leak Rate'
    },
    
    # =========================================================================
    # SALES METRICS - Lead Time & Deal Upgrade (Pages 13-14)
    # =========================================================================
    'Average Lead Time': {
        'image': 'discovery_intro_blended_quarterly/quarterly_avg_lead_time_completed.png',
        'csv': 'discovery_intro/quarterly_discovery_intro_blended.csv',
        'metric': 'Avg Lead Time (Days)(Completed)',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Avg Lead Time (Days)(Completed)'
    },
    'Deal Upgrade Visits': {
        'image': 'deal_upgrade_quarterly/quarterly_visits.png',
        'csv': 'deal_upgrade/quarterly_deal_upgrade.csv',
        'metric': 'Visits',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly DU Visits'
    },
    'Deal Upgrade CVR': {
        'image': 'deal_upgrade_quarterly/quarterly_conversion_rate.png',
        'csv': 'deal_upgrade/quarterly_deal_upgrade.csv',
        'metric': 'Conversion Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly DU Conversion Rate'
    },
    
    # =========================================================================
    # SALES METRICS - Pro Site Funnel (Page 15)
    # =========================================================================
    'Pro Site Visits': {
        'image': 'pro_site_quarterly/quarterly_visits.png',
        'csv': 'pro_site/quarterly_pro_site.csv',
        'metric': 'Visits',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly PS Visits'
    },
    'Pro Site CVR': {
        'image': 'pro_site_quarterly/quarterly_conversion_rate.png',
        'csv': 'pro_site/quarterly_pro_site.csv',
        'metric': 'Conversion Rate',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly PS Conversion Rate'
    },
    
    # =========================================================================
    # SALES METRICS - Booked Calls (Page 16)
    # =========================================================================
    'Booked Calls - Closers (Discovery Call)': {
        'image': 'discovery_call_quarterly/quarterly_booked_calls_completed.png',
        'csv': 'discovery_intro/quarterly_discovery_call.csv',
        'metric': 'Booked Calls (Completed)',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Booked Calls (Completed) - Discovery'
    },
    'Booked Calls - Setters (Intro Call)': {
        'image': 'intro_call_quarterly/quarterly_booked_calls_completed.png',
        'csv': 'discovery_intro/quarterly_intro_call.csv',
        'metric': 'Booked Calls (Completed)',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Booked Calls (Completed) - Intro'
    },
    
    # =========================================================================
    # SALES METRICS - Sales Pipeline: Calls (Pages 17-18)
    # =========================================================================
    'Scheduled Calls': {
        'image': 'sales_tracker_quarterly/quarterly_sched_calls.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Sched. calls',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Scheduled calls'
    },
    'Live Calls': {
        'image': 'sales_tracker_quarterly/quarterly_live_calls.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Live calls',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Live Calls'
    },
    'Show Rate': {
        'image': 'sales_tracker_quarterly/quarterly_show_pct.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Show %',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Show %'
    },
    
    # =========================================================================
    # SALES METRICS - Offers (Page 19)
    # =========================================================================
    'Offers': {
        'image': 'sales_tracker_quarterly/quarterly_offers.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Offers',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Offers'
    },
    'Offer Rate': {
        'image': 'sales_tracker_quarterly/quarterly_offer_pct.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Offer %',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Offer %'
    },
    
    # =========================================================================
    # SALES METRICS - Closes (Page 20)
    # =========================================================================
    'Closes': {
        'image': 'sales_tracker_quarterly/quarterly_close_1.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Close 1',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Closes'
    },
    'Offer to Close Rate': {
        'image': 'sales_tracker_quarterly/quarterly_offer_to_close_pct.png',
        'csv': 'sales_tracker/quarterly_sales_tracker.csv',
        'metric': 'Offer to Close %',
        'date_col': 'Date Range',
        'goal_metric': 'Quarterly Offer to Close %'
    },
}

print(f"✓ Chart configuration loaded: {len(CHART_CONFIG)} charts mapped")
print(f"  Charts with goals: {sum(1 for c in CHART_CONFIG.values() if c.get('goal_metric'))}")
# Out:
# ✓ Chart configuration loaded: 25 charts mapped
#   Charts with goals: 25

# %% [markdown]
# ### Section 4: Utility Functions - Value Parsing and Formatting

# %%
# =============================================================================
# SECTION 4: UTILITY FUNCTIONS - VALUE PARSING AND FORMATTING
# =============================================================================
# Helper functions for parsing values, formatting output, and determining
# metric types (percentage vs absolute values)

def parse_reference_dates(ref_file):
    """
    Parse analysis_ref_date.csv to extract QUARTER date range for QBR.
    
    How it works:
    - Reads the CSV line by line
    - Extracts Quarter Start Date and Quarter End Date
    - Returns formatted date strings for filename and display
    
    Returns:
        dict with keys: quarter_start, quarter_end, date_range_filename, date_range_display
    """
    if not os.path.exists(ref_file):
        print(f"  ⚠ Reference file not found: {ref_file}")
        return None
    
    try:
        ref_df = pd.read_csv(ref_file, header=None)
        ref_dict = dict(zip(ref_df[0], ref_df[1]))
        
        # Get Quarter Start Date and Quarter End Date for QBR
        quarter_start = ref_dict.get('Quarter Start Date', '')
        quarter_end = ref_dict.get('Quarter End Date', '')
        
        # Format for filename: MM-DD-YYYY
        start_parts = quarter_start.split('/')
        end_parts = quarter_end.split('/')
        
        if len(start_parts) == 3 and len(end_parts) == 3:
            date_range_filename = f"{start_parts[0]}-{start_parts[1]}-{start_parts[2]}_to_{end_parts[0]}-{end_parts[1]}-{end_parts[2]}"
            date_range_display = f"{quarter_start} to {quarter_end}"
        else:
            date_range_filename = "unknown_date_range"
            date_range_display = "Unknown Date Range"
        
        return {
            'quarter_start': quarter_start,
            'quarter_end': quarter_end,
            'date_range_filename': date_range_filename,
            'date_range_display': date_range_display
        }
    except Exception as e:
        print(f"  ⚠ Error parsing reference dates: {e}")
        return None


def parse_value(value):
    """
    Parse a value that might be percentage string, number, or other format.
    
    Examples:
    - "50%" -> 50.0 (keeps as percentage number)
    - "+12.35%" -> 12.35
    - "33,821" -> 33821.0
    - 100 -> 100.0
    
    Returns:
        float or None if unparseable
    """
    if pd.isna(value):
        return None
    
    if isinstance(value, (int, float)):
        return float(value)
    
    value_str = str(value).strip().lstrip('+')
    
    # Handle percentage - just remove the % sign, keep the number
    if value_str.endswith('%'):
        try:
            return float(value_str.rstrip('%'))
        except ValueError:
            return None
    
    # Handle regular number (remove commas)
    try:
        return float(value_str.replace(',', ''))
    except ValueError:
        return None


def format_value(value, is_percentage=False, decimals=2):
    """
    Format numeric value for display in report.
    
    Args:
        value: The numeric value
        is_percentage: If True, add % sign
        decimals: Decimal places to show
    """
    if value is None or pd.isna(value):
        return 'N/A'
    
    if is_percentage:
        return f"{value:.{decimals}f}%"
    else:
        if abs(value) >= 1000:
            return f"{value:,.{decimals}f}"
        return f"{value:.{decimals}f}"


def format_change(value, is_percentage=False):
    """
    Format a change value with + or - sign for QoQ comparisons.
    """
    if value is None or pd.isna(value):
        return 'N/A'
    
    sign = '+' if value > 0 else ''
    if is_percentage:
        return f"{sign}{value:.2f}%"
    return f"{sign}{value:.2f}"


def is_percentage_metric(metric_name):
    """
    Determine if metric should be displayed as percentage.
    Checks for keywords: rate, cvr, %, pct, percentage
    """
    metric_lower = metric_name.lower()
    pct_keywords = ['rate', 'cvr', '%', 'pct', 'percentage']
    return any(kw in metric_lower for kw in pct_keywords)


print("✓ Value parsing and formatting functions loaded")
# Out:
# ✓ Value parsing and formatting functions loaded

# %% [markdown]
# ### Section 5: Utility Functions - Trend and Spike Detection

# %%
# =============================================================================
# SECTION 5: UTILITY FUNCTIONS - TREND AND SPIKE DETECTION
# =============================================================================
# Statistical functions for analyzing quarterly time series data
# Uses two methods for robust trend detection:
# 1. Linear Regression with p-value (for clean data)
# 2. First-half vs Second-half average comparison (for volatile data)
#
# QBR Trend Periods:
# - 4 quarters = 1 year (short-term)
# - 6 quarters = 1.5 years
# - 8 quarters = 2 years (medium-term)
# - 12 quarters = 3 years (long-term)

def calculate_trend(values, p_value_threshold=0.05, min_points=4, half_comparison_threshold=0.05):
    """
    Calculate trend direction using a HYBRID approach:
    
    Method 1: Linear Regression with p-value
    - If p-value ≤ threshold → use slope direction (statistically significant)
    
    Method 2: First-half vs Second-half average comparison (for volatile data)
    - If p-value > threshold (volatile), compare averages of first half vs second half
    - If second half avg is significantly higher → Rising
    - If second half avg is significantly lower → Falling
    - Otherwise → Stable
    
    Args:
        values: List of values (oldest to newest)
        p_value_threshold: Significance level for linear regression (default 0.05)
        min_points: Minimum data points required
        half_comparison_threshold: Minimum % difference between halves to detect trend (default 5%)
    
    Returns:
        str: 'rising', 'falling', 'stable', or 'insufficient data'
    """
    clean_values = [v for v in values if v is not None and not pd.isna(v)]
    
    if len(clean_values) < min_points:
        return 'insufficient data'
    
    n = len(clean_values)
    x = np.arange(n)
    y = np.array(clean_values)
    
    # Method 1: Linear Regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
    
    # If p-value is significant, use linear regression result
    if p_value <= p_value_threshold:
        if slope > 0:
            return 'rising'
        elif slope < 0:
            return 'falling'
        else:
            return 'stable'
    
    # Method 2: First-half vs Second-half comparison (for volatile data)
    # Split data into two halves
    mid_point = n // 2
    first_half = clean_values[:mid_point]
    second_half = clean_values[mid_point:]
    
    if len(first_half) < 2 or len(second_half) < 2:
        return 'stable'
    
    first_half_avg = np.mean(first_half)
    second_half_avg = np.mean(second_half)
    
    # Calculate percentage change between halves
    if first_half_avg != 0:
        pct_change = (second_half_avg - first_half_avg) / abs(first_half_avg)
    else:
        pct_change = 0
    
    # Classify based on percentage change between halves
    if pct_change > half_comparison_threshold:
        return 'rising'
    elif pct_change < -half_comparison_threshold:
        return 'falling'
    else:
        return 'stable'


def calculate_multi_period_trends(values):
    """
    Calculate trends over multiple time horizons using hybrid approach.
    
    For QBR (Quarterly), we analyze:
    - 4-quarter trend (short term = 1 year)
    - 6-quarter trend (1.5 years)
    - 8-quarter trend (medium term = 2 years)  
    - 12-quarter trend (long term = 3 years)
    
    Different thresholds for different periods:
    - 4Q: 8% change between halves needed (short term = more noise tolerance)
    - 6Q: 7% change between halves needed
    - 8Q: 6% change between halves needed
    - 12Q: 5% change between halves needed (long term = smaller changes are meaningful)
    
    Returns:
        dict with 'short', 'medium_short', 'medium', 'long' keys, each containing:
        - 'period': number of quarters
        - 'trend': 'rising', 'falling', 'stable', or 'insufficient data'
    """
    # Trend periods configuration
    # 4 quarters = 1 year, 6 quarters = 1.5 years, 8 quarters = 2 years, 12 quarters = 3 years
    short_period = 4             # 4 quarters (1 year)
    medium_short_period = 6      # 6 quarters (1.5 years)
    medium_period = 8            # 8 quarters (2 years)
    long_period = 12             # 12 quarters (3 years)
    
    trends = {
        'short': {'period': short_period, 'trend': 'insufficient data'},
        'medium_short': {'period': medium_short_period, 'trend': 'insufficient data'},
        'medium': {'period': medium_period, 'trend': 'insufficient data'},
        'long': {'period': long_period, 'trend': 'insufficient data'},
    }
    
    num_points = len(values)
    
    # Short-term trend (need at least 4 quarters = 1 year)
    if num_points >= short_period:
        trends['short']['trend'] = calculate_trend(
            values[-short_period:], 
            p_value_threshold=0.05, 
            min_points=4,
            half_comparison_threshold=0.08  # 8% for 4 quarters
        )
    
    # Medium-short trend (need at least 6 quarters = 1.5 years)
    if num_points >= medium_short_period:
        trends['medium_short']['trend'] = calculate_trend(
            values[-medium_short_period:], 
            p_value_threshold=0.05, 
            min_points=4,
            half_comparison_threshold=0.07  # 7% for 6 quarters
        )
    
    # Medium-term trend (need at least 8 quarters = 2 years)
    if num_points >= medium_period:
        trends['medium']['trend'] = calculate_trend(
            values[-medium_period:], 
            p_value_threshold=0.05, 
            min_points=4,
            half_comparison_threshold=0.06  # 6% for 8 quarters
        )
    
    # Long-term trend (need at least 12 quarters = 3 years)
    if num_points >= long_period:
        trends['long']['trend'] = calculate_trend(
            values[-long_period:], 
            p_value_threshold=0.05, 
            min_points=6,
            half_comparison_threshold=0.05  # 5% for 12 quarters
        )
    
    return trends


def classify_vs_average(current, avg_value, num_periods, near_threshold=None):
    """
    Classify current value relative to N-quarter average.
    
    Args:
        current: Current quarter's value
        avg_value: N-quarter rolling average
        num_periods: Number of periods used in average (for labeling)
        near_threshold: Percentage threshold for "Near" classification (default from CONFIG)
    
    Returns:
        tuple: (classification_str, num_periods)
        - classification_str: 'High CV vs {N}Q Avg', 'Low CV vs {N}Q Avg', or 'Normal (Near Avg)'
        - num_periods: The number of periods used in the average
        
    CV = Current Value
    """
    if near_threshold is None:
        near_threshold = CONFIG['near_threshold_pct']
        
    if current is None or avg_value is None or avg_value == 0:
        return 'Normal', num_periods
    
    pct_diff = (current - avg_value) / abs(avg_value)
    
    # Above threshold (>5% by default) = High
    if pct_diff > near_threshold:
        return f'High CV vs {num_periods}Q Avg', num_periods
    # Below threshold (<-5% by default) = Low  
    elif pct_diff < -near_threshold:
        return f'Low CV vs {num_periods}Q Avg', num_periods
    # Within ±5% = Near/Normal
    return 'Normal (Near Avg)', num_periods


def detect_spike_or_dip(current, avg_value, std_value):
    """
    Detect if current quarter represents a spike or dip using two rules:
    
    1. Statistical rule: ±2 standard deviations from mean
    2. Relative rule: ±25% vs average (configurable)
    
    Args:
        current: Current quarter's value
        avg_value: Rolling average
        std_value: Standard deviation
    
    Returns:
        str: 'Spike', 'Dip', or 'No anomaly'
    """
    if current is None or avg_value is None:
        return 'No anomaly'
    
    spike_pct_threshold = CONFIG['spike_threshold_pct']  # 25%
    spike_std_threshold = CONFIG['spike_threshold_std']  # 2
    
    # Rule 1: Statistical (±2 std deviations)
    if std_value is not None and std_value > 0:
        upper_bound_std = avg_value + (spike_std_threshold * std_value)
        lower_bound_std = avg_value - (spike_std_threshold * std_value)
        
        if current > upper_bound_std:
            return 'Spike'
        elif current < lower_bound_std:
            return 'Dip'
    
    # Rule 2: Relative (±25% from average)
    if avg_value != 0:
        pct_diff = (current - avg_value) / abs(avg_value)
        
        if pct_diff > spike_pct_threshold:
            return 'Spike'
        elif pct_diff < -spike_pct_threshold:
            return 'Dip'
    
    return 'No anomaly'


print("✓ Trend and spike detection functions loaded (hybrid: p-value + half comparison)")
print("  Trend periods: 4Q, 6Q, 8Q, 12Q")
# Out:
# ✓ Trend and spike detection functions loaded (hybrid: p-value + half comparison)
#   Trend periods: 4Q, 6Q, 8Q, 12Q

# %% [markdown]
# ### Section 6: Data Loading Functions

# %%
# =============================================================================
# SECTION 6: DATA LOADING FUNCTIONS
# =============================================================================
# Functions to load CSV and Excel files, extract time series data
# Data is filtered to only include records up to the reporting quarter end date

# Global variable for reporting quarter end date filter
REPORTING_QUARTER_END = None

def set_reporting_quarter_end(date_info):
    """
    Set the global reporting quarter end date used to filter data.
    Only data up to this date will be included in analysis.
    """
    global REPORTING_QUARTER_END
    quarter_end_str = date_info.get('quarter_end', '')
    
    formats = ['%m/%d/%Y', '%Y-%m-%d', '%m/%d/%y']
    for fmt in formats:
        try:
            REPORTING_QUARTER_END = datetime.strptime(quarter_end_str, fmt)
            print(f"  Data filter: Only including data up to {REPORTING_QUARTER_END.strftime('%m/%d/%Y')}")
            return
        except ValueError:
            continue
    
    print(f"  ⚠ Could not parse quarter end date: {quarter_end_str}")
    REPORTING_QUARTER_END = None


def load_csv_data(csv_path):
    """Load and clean a CSV file, removing empty rows."""
    if not os.path.exists(csv_path):
        return None
    try:
        df = pd.read_csv(csv_path)
        df = df.dropna(how='all')
        return df
    except Exception as e:
        print(f"  ⚠ Error loading CSV: {e}")
        return None


def load_excel_metrics(xlsx_path):
    """Load metrics table from Excel file, removing empty rows and columns."""
    if not os.path.exists(xlsx_path):
        return None
    try:
        df = pd.read_excel(xlsx_path)
        df = df.dropna(how='all').dropna(axis=1, how='all')
        return df
    except Exception as e:
        print(f"  ⚠ Error loading Excel: {e}")
        return None


def parse_date_for_sorting(date_str):
    """
    Parse date string to datetime object for sorting and filtering.
    For date ranges like "01/01/2024 - 03/31/2024", extracts the END date.
    """
    if pd.isna(date_str):
        return None
    
    date_str = str(date_str).strip()
    
    # Extract END date from date ranges
    if ' - ' in date_str:
        date_str = date_str.split(' - ')[-1].strip()
    
    # Skip non-date strings
    if date_str.lower().startswith('quarter') or len(date_str) < 6:
        return None
    
    formats = ['%m/%d/%Y', '%Y-%m-%d', '%m/%d/%y', '%d/%m/%Y', '%m-%d-%Y']
    
    for fmt in formats:
        try:
            return datetime.strptime(date_str, fmt)
        except ValueError:
            continue
    
    return None


def extract_metric_series(df, metric_col, date_col):
    """
    Extract time series for a metric column from dataframe.
    
    Filtering:
    - Only includes data where date <= REPORTING_QUARTER_END
    - Data beyond the reporting quarter is ignored
    
    Sorting:
    - Returns data sorted chronologically (oldest first, newest last)
    - values[-1] = most recent quarter (the reporting quarter)
    - values[-2] = previous quarter
    
    Returns:
        List of (date_string, value) tuples sorted oldest to newest
    """
    global REPORTING_QUARTER_END
    
    if df is None or metric_col not in df.columns:
        return []
    
    raw_data = []
    
    # Handle two-column date format: [Start Date, End Date]
    if isinstance(date_col, list) and len(date_col) == 2:
        start_col, end_col = date_col
        if start_col in df.columns and end_col in df.columns:
            for idx, row in df.iterrows():
                date_display = f"{row[start_col]} - {row[end_col]}"
                value = parse_value(row[metric_col])
                sort_date = parse_date_for_sorting(str(row[end_col]))
                if value is not None:
                    raw_data.append({
                        'date_display': date_display,
                        'value': value,
                        'sort_date': sort_date
                    })
    # Handle single date column
    elif date_col in df.columns:
        for idx, row in df.iterrows():
            date_display = str(row[date_col])
            value = parse_value(row[metric_col])
            sort_date = parse_date_for_sorting(date_display)
            if value is not None:
                raw_data.append({
                    'date_display': date_display,
                    'value': value,
                    'sort_date': sort_date
                })
    
    if not raw_data:
        return []
    
    # Separate records with and without parseable dates
    with_dates = [d for d in raw_data if d['sort_date'] is not None]
    without_dates = [d for d in raw_data if d['sort_date'] is None]
    
    # Filter: only include data up to reporting quarter end date
    if REPORTING_QUARTER_END is not None:
        with_dates = [d for d in with_dates if d['sort_date'] <= REPORTING_QUARTER_END]
    
    # Sort chronologically: oldest first, newest last
    with_dates.sort(key=lambda x: x['sort_date'])
    
    # Build result list
    result = [(d['date_display'], d['value']) for d in with_dates]
    result.extend([(d['date_display'], d['value']) for d in without_dates])
    
    return result


print("✓ Data loading functions loaded")
# Out:
# ✓ Data loading functions loaded

# %% [markdown]
# ### Section 7: Chart Insight Generation

# %%
# =============================================================================
# SECTION 7: CHART INSIGHT GENERATION
# =============================================================================
# Functions to calculate insights from chart data with multi-period trends
# For QBR: uses DYNAMIC average period based on available data
# - If 6+ quarters available → 6-quarter average
# - If fewer quarters → use all available (e.g., 3-quarter average)

# Global variable to cache goal targets
GOAL_TARGETS = {}

# Metrics stored as decimals that need conversion to percentages
# Only specific files store values as decimals (e.g., 0.20 for 20%)
DECIMAL_METRICS = {
    'general_newsletter/quarterly_table.csv': ['Growth Rate', 'Newsletter CVR %', 'Leak Rate', 'Unsub Rate']
}

def load_goal_targets():
    """
    Load goal targets from target_reference.csv.
    File format: metric_name,target_value
    
    Returns:
        dict mapping metric names to target values
    """
    global GOAL_TARGETS
    
    if not os.path.exists(TARGET_FILE):
        print(f"  ⚠ Target file not found: {TARGET_FILE}")
        return {}
    
    try:
        targets = {}
        with open(TARGET_FILE, 'r') as f:
            lines = f.readlines()
        
        for line in lines:
            line = line.strip()
            # Skip empty lines, headers, and section dividers
            if not line or line.startswith('Metric') or line.startswith('=') or line.startswith('NEWSLETTER') or line.startswith('DEAL') or line.startswith('PRO') or line.startswith('DISCOVERY') or line.startswith('SALES') or line.startswith('GENERAL'):
                continue
            
            # Parse metric,value pairs
            if ',' in line:
                parts = line.split(',', 1)
                metric_name = parts[0].strip()
                if len(parts) > 1 and parts[1].strip():
                    try:
                        target_value = float(parts[1].strip())
                        targets[metric_name] = target_value
                    except ValueError:
                        # No target value for this metric
                        pass
        
        GOAL_TARGETS = targets
        return targets
    
    except Exception as e:
        print(f"  ⚠ Error loading target file: {e}")
        return {}


def get_goal_target(goal_metric_name):
    """
    Get the goal target value for a metric.
    
    Args:
        goal_metric_name: The metric name as it appears in target_reference.csv
        
    Returns:
        Target value (float) or None if no goal defined
    """
    global GOAL_TARGETS
    
    # Load targets if not already loaded
    if not GOAL_TARGETS:
        load_goal_targets()
    
    if not goal_metric_name:
        return None
    
    return GOAL_TARGETS.get(goal_metric_name)


def needs_decimal_conversion(csv_path, metric_name):
    """
    Check if this metric needs decimal-to-percent conversion.
    
    Only general_newsletter/quarterly_table.csv stores certain metrics as decimals.
    All other CSV files are already in percentage form.
    """
    for csv_key, metrics in DECIMAL_METRICS.items():
        if csv_key in csv_path:
            if any(m.lower() == metric_name.lower() for m in metrics):
                return True
    return False


def get_chart_data_insights(chart_name, config):
    """
    Load chart data and calculate all insights for the reporting quarter.
    
    DYNAMIC AVERAGE PERIOD:
    - Uses up to 6 quarters for average calculation
    - If fewer quarters available, uses all available data
    - Reports the actual number of periods used (e.g., "3-quarter average")
    
    Handles:
    - Absolute value metrics (converts negative to positive)
    - Inverted metrics (where lower is better)
    - Decimal to percent conversion (only for specific files/metrics)
    - Multi-period trend analysis with Linear Regression
    - Spike/Dip detection
    - Goal attainment comparison
    
    Returns dict with:
    - current_value, previous_value
    - qoq_change_abs, qoq_change_pct
    - avg_value, avg_std, avg_periods (DYNAMIC - actual periods used)
    - vs_average classification
    - spike_dip detection
    - multi-period trends
    - goal_target, goal_met, goal_diff_pct (if goal defined)
    """
    csv_path = os.path.join(OUTPUTS_PATH, config['csv'])
    df = load_csv_data(csv_path)
    
    insights = {
        'chart_name': chart_name,
        'csv_source': config['csv'],
        'image_source': config['image'],
        'metric': config['metric'],
        'data_available': False,
        'data_points': 0
    }
    
    if df is None:
        insights['error'] = 'CSV file not found'
        return insights
    
    # Extract filtered and sorted time series
    series = extract_metric_series(df, config['metric'], config['date_col'])
    
    if len(series) < 2:
        insights['error'] = f'Not enough data points ({len(series)})'
        insights['data_points'] = len(series)
        return insights
    
    insights['data_available'] = True
    insights['data_points'] = len(series)
    
    # Extract values (series is now 2-tuple: (date, value))
    values = [v for _, v in series]
    
    # Check if this metric should use absolute values
    is_absolute_metric = any(abs_m.lower() in config['metric'].lower() 
                            for abs_m in ABSOLUTE_VALUE_METRICS)
    
    if is_absolute_metric:
        values = [abs(v) for v in values]
    
    # Current = last value (reporting quarter)
    # Previous = second-to-last value (quarter before)
    current = values[-1]
    previous = values[-2]
    
    # Check if this specific file/metric needs decimal conversion
    is_pct_metric = is_percentage_metric(config['metric'])
    needs_conversion = needs_decimal_conversion(config['csv'], config['metric'])
    
    if is_pct_metric and needs_conversion:
        # This metric is stored as decimal (e.g., 0.20 for 20%), convert to percentage
        current_display = current * 100
        previous_display = previous * 100
    else:
        # Already in percentage form or not a percentage metric
        current_display = current
        previous_display = previous
    
    insights['current_value'] = current_display
    insights['previous_value'] = previous_display
    insights['current_date'] = series[-1][0]
    insights['previous_date'] = series[-2][0]
    insights['is_absolute_metric'] = is_absolute_metric
    insights['is_pct_metric'] = is_pct_metric
    insights['needs_conversion'] = needs_conversion
    
    # Quarter-over-quarter change calculation
    if previous != 0:
        insights['qoq_change_pct'] = (current - previous) / abs(previous)
        insights['qoq_change_abs'] = current_display - previous_display
    else:
        insights['qoq_change_pct'] = None
        insights['qoq_change_abs'] = current_display - previous_display
    
    # ==========================================================================
    # DYNAMIC AVERAGE CALCULATION
    # Uses up to 6 quarters, but adapts to available data
    # ==========================================================================
    max_periods = CONFIG['quarters_for_average']  # Default: 6
    actual_periods = min(len(values), max_periods)  # Use available or max
    
    last_n = values[-actual_periods:]
    if is_pct_metric and needs_conversion:
        last_n_display = [v * 100 for v in last_n]
    else:
        last_n_display = last_n
    
    insights['avg_value'] = np.mean(last_n_display)
    insights['avg_std'] = np.std(last_n_display) if len(last_n_display) >= 2 else 0
    insights['avg_periods'] = actual_periods  # Store actual number of periods used
    
    # Classification vs N-quarter average (dynamic label)
    insights['vs_average'], _ = classify_vs_average(
        current_display, 
        insights['avg_value'], 
        actual_periods
    )
    
    # Spike/Dip detection
    insights['spike_dip'] = detect_spike_or_dip(
        current_display, 
        insights['avg_value'], 
        insights['avg_std']
    )
    
    # Multi-period trend analysis
    insights['trends'] = calculate_multi_period_trends(values)
    
    # ==========================================================================
    # GOAL ATTAINMENT - Compare current value to target from target_reference.csv
    # ==========================================================================
    goal_metric_name = config.get('goal_metric')
    if goal_metric_name:
        target = get_goal_target(goal_metric_name)
        if target is not None:
            insights['goal_target'] = target
            insights['goal_metric_name'] = goal_metric_name
            
            # Check if goal is met (for inverted metrics, lower is better)
            is_inverted = any(inv.lower() in config['metric'].lower() for inv in INVERTED_METRICS)
            
            if is_inverted:
                # For inverted metrics: actual <= target means goal met
                insights['goal_met'] = current_display <= target
            else:
                # For normal metrics: actual >= target means goal met
                insights['goal_met'] = current_display >= target
            
            # Calculate difference from goal
            if target != 0:
                insights['goal_diff_pct'] = ((current_display - target) / abs(target)) * 100
            else:
                insights['goal_diff_pct'] = 0 if current_display == 0 else 100
    
    return insights


def format_trend_with_arrow(trend):
    """Convert trend string to display format with arrow."""
    if trend == 'rising':
        return '↑ Rising'
    elif trend == 'falling':
        return '↓ Falling'
    elif trend == 'stable':
        return '→ Stable'
    else:
        return None  # Return None for insufficient data


print("✓ Chart insight generation functions loaded")
print(f"  Goal targets loaded: {len(GOAL_TARGETS) if GOAL_TARGETS else 'will load on first use'}")
# Out:
# ✓ Chart insight generation functions loaded
#   Goal targets loaded: will load on first use

# %% [markdown]
# ### Section 8: Generate Chart Insight Text (QBR Format)

# %%
# =============================================================================
# SECTION 8: GENERATE CHART INSIGHT TEXT (QBR FORMAT)
# =============================================================================
# Generates human-readable insight paragraphs from calculated insights
# Customized for Quarterly Business Review with all required elements:
# - Current vs Previous (QoQ)
# - DYNAMIC N-quarter average comparison (based on available data)
# - Goal attainment (if goals defined)
# - Multi-period trends (4, 6, 8, 12 quarters) - ONLY if data available
#
# KEY CHANGES:
# 1. Average period is dynamic (shows "3-quarter" if only 3 data points)
# 2. Trend line is SKIPPED entirely if insufficient data (no error message)
# 3. Added 6-quarter trend period

def generate_chart_insight_text(insights, metric_name):
    """
    Generate human-readable insight paragraph from calculated insights.
    
    QBR Output format (paragraph style):
    - Line 1: Current value vs previous quarter (QoQ change)
    - Line 2: Performance vs N-quarter average with classification (DYNAMIC N)
    - Line 3: Goal attainment (if goal defined, otherwise skipped)
    - Line 4: Trend direction over 4/6/8/12 quarters (ONLY if data available, otherwise SKIPPED)
    
    Features:
    - Zero change shows "no change from previous quarter"
    - Percentages always show 2 decimal places (XX.XX%)
    - Uses (favorable)/(unfavorable) labels for inverted metrics
    - Goal attainment shows met/missed with variance
    - DYNAMIC average period based on available data
    - Trend line OMITTED if insufficient data (not shown as error)
    """
    if not insights.get('data_available', False):
        error_msg = insights.get('error', 'Data unavailable')
        return f"⚠ {error_msg}"
    
    is_pct = insights.get('is_pct_metric', is_percentage_metric(metric_name))
    is_inverted = any(inv.lower() in metric_name.lower() for inv in INVERTED_METRICS)
    
    current = insights['current_value']
    previous = insights['previous_value']
    qoq_pct = insights.get('qoq_change_pct')
    qoq_abs = insights.get('qoq_change_abs', 0)
    avg_value = insights['avg_value']
    avg_periods = insights['avg_periods']  # Dynamic number of periods
    vs_avg = insights['vs_average']
    trends = insights.get('trends', {})
    data_points = insights['data_points']
    
    lines = []
    
    # Format values based on metric type (always 2 decimal places for percentages)
    if is_pct:
        curr_str = f"{current:.2f}%"
        prev_str = f"{previous:.2f}%"
        avg_str = f"{avg_value:.2f}%"
        change_str = f"{abs(qoq_abs):.2f}%"
    else:
        curr_str = f"{current:,.0f}" if current >= 100 else f"{current:.2f}"
        prev_str = f"{previous:,.0f}" if abs(previous) >= 100 else f"{previous:.2f}"
        avg_str = f"{avg_value:,.0f}" if avg_value >= 100 else f"{avg_value:.2f}"
        change_str = f"{abs(qoq_abs):,.0f}" if abs(qoq_abs) >= 100 else f"{abs(qoq_abs):.2f}"
    
    # ==========================================================================
    # LINE 1: Current quarter vs previous quarter (QoQ change)
    # ==========================================================================
    if qoq_pct is not None:
        # Check for zero or near-zero change
        if abs(qoq_pct) < 0.001:  # Less than 0.1% change
            lines.append(f"• Current quarter: {curr_str} vs {prev_str} last quarter (no change QoQ)")
        else:
            direction = "+" if qoq_abs > 0 else ""
            pct_change_str = f"{qoq_pct*100:+.1f}%"
            
            if is_inverted:
                # For inverted metrics: down = good, up = bad
                quality = "(favorable)" if qoq_pct < 0 else "(unfavorable)"
            else:
                # For normal metrics: up = good, down = bad
                quality = "(favorable)" if qoq_pct > 0 else "(unfavorable)"
            
            lines.append(f"• Current quarter: {curr_str} vs {prev_str} last quarter ({direction}{change_str}, {pct_change_str} QoQ) {quality}")
    else:
        lines.append(f"• Current quarter: {curr_str} (previous: {prev_str})")
    
    # ==========================================================================
    # LINE 2: Performance vs N-quarter average with classification (DYNAMIC)
    # Uses actual number of periods available (e.g., 3-quarter if only 3 data points)
    # ==========================================================================
    if avg_value != 0:
        pct_from_avg = ((current - avg_value) / abs(avg_value)) * 100
        above_below = "above" if pct_from_avg > 0 else "below"
        lines.append(f"• Performance is {abs(pct_from_avg):.1f}% {above_below} the {avg_periods}-quarter average (avg = {avg_str}) → {vs_avg}")
    else:
        lines.append(f"• {avg_periods}-quarter average: {avg_str} → {vs_avg}")
    
    # ==========================================================================
    # LINE 3: Goal attainment (only if goal defined)
    # ==========================================================================
    if 'goal_target' in insights:
        target = insights['goal_target']
        goal_met = insights.get('goal_met', False)
        goal_diff_pct = insights.get('goal_diff_pct', 0)
        
        # Format target value
        if is_pct:
            target_str = f"{target:.2f}%"
        else:
            target_str = f"{target:,.0f}" if target >= 100 else f"{target:.2f}"
        
        if goal_met:
            if is_inverted:
                # For inverted metrics, being under target is good
                lines.append(f"• Goal met: Yes (target = {target_str}; actual = {curr_str}; {abs(goal_diff_pct):.1f}% below goal)")
            else:
                # For normal metrics, being above target is good
                lines.append(f"• Goal met: Yes (target = {target_str}; actual = {curr_str}; +{abs(goal_diff_pct):.1f}% above goal)")
        else:
            if is_inverted:
                # For inverted metrics, being over target is bad
                lines.append(f"• Goal missed: (target = {target_str}; actual = {curr_str}; +{abs(goal_diff_pct):.1f}% above goal)")
            else:
                # For normal metrics, being under target is bad
                lines.append(f"• Goal missed: (target = {target_str}; actual = {curr_str}; {abs(goal_diff_pct):.1f}% below goal)")
    
    # ==========================================================================
    # LINE 4: Trend direction over multiple periods (4, 6, 8, 12 quarters)
    # ONLY shows trends with sufficient data - SKIPS entirely if no valid trends
    # ==========================================================================
    trend_parts = []
    
    # Short-term trend (4 quarters = 1 year)
    short_trend = format_trend_with_arrow(trends.get('short', {}).get('trend'))
    if short_trend:
        trend_parts.append(f"4Q: {short_trend}")
    
    # Medium-short trend (6 quarters = 1.5 years)
    medium_short_trend = format_trend_with_arrow(trends.get('medium_short', {}).get('trend'))
    if medium_short_trend:
        trend_parts.append(f"6Q: {medium_short_trend}")
    
    # Medium-term trend (8 quarters = 2 years)
    medium_trend = format_trend_with_arrow(trends.get('medium', {}).get('trend'))
    if medium_trend:
        trend_parts.append(f"8Q: {medium_trend}")
    
    # Long-term trend (12 quarters = 3 years)
    long_trend = format_trend_with_arrow(trends.get('long', {}).get('trend'))
    if long_trend:
        trend_parts.append(f"12Q: {long_trend}")
    
    # ONLY add trend line if we have at least one valid trend
    # If no valid trends (all insufficient data), SKIP the trend line entirely
    if trend_parts:
        lines.append(f"• Trend: {' | '.join(trend_parts)}")
    # else: Skip trend line entirely - don't show "Not enough data" message
    
    return '\n'.join(lines)


print("✓ Chart insight text generation function loaded")
print("  - Dynamic average period (uses actual data points available)")
print("  - Trend periods: 4Q, 6Q, 8Q, 12Q")
print("  - Trend line skipped if insufficient data (no error message)")
# Out:
# ✓ Chart insight text generation function loaded
#   - Dynamic average period (uses actual data points available)
#   - Trend periods: 4Q, 6Q, 8Q, 12Q
#   - Trend line skipped if insufficient data (no error message)

# %% [markdown]
# ### Section 9: Section Summary Generation (Executive Summary)

# %%
# =============================================================================
# SECTION 9: SECTION SUMMARY GENERATION (EXECUTIVE SUMMARY)
# =============================================================================
# Functions to generate executive summary bullets from metrics tables
# Analyzes top improvements and concerns based on QoQ changes

def generate_section_summary(df, section_name='metrics'):
    """
    Generate summary bullets from metrics table for executive summary.
    
    Analyzes the QoQ column to find:
    - Top 3-5 improvements (largest positive changes)
    - Top 3-5 concerns (largest negative changes)
    
    Args:
        df: DataFrame with metrics (must have a QoQ or similar column)
        section_name: 'newsletter' or 'sales' for labeling
    
    Returns:
        dict with 'improvements', 'concerns', 'summary' keys
    """
    if df is None or df.empty:
        return {
            'improvements': [],
            'concerns': [],
            'summary': f'No {section_name} data available'
        }
    
    # Find the QoQ/change column
    change_col = None
    for col in df.columns:
        col_lower = str(col).lower()
        if 'qoq' in col_lower or 'change' in col_lower or 'mom' in col_lower:
            change_col = col
            break
    
    # If no change column found, use last column
    if change_col is None:
        change_col = df.columns[-1]
    
    # Find the metric name column (usually first column)
    metric_col = df.columns[0]
    
    # Parse changes and separate into improvements/concerns
    improvements = []
    concerns = []
    
    for _, row in df.iterrows():
        metric_name = str(row[metric_col])
        change_val = row[change_col]
        
        try:
            # Parse the change value
            change_str = str(change_val).replace('%', '').replace('+', '').strip()
            change_num = float(change_str)
            
            # Check if this is an inverted metric
            is_inverted = any(inv.lower() in metric_name.lower() for inv in INVERTED_METRICS)
            
            if is_inverted:
                # For inverted metrics: negative change = improvement
                if change_num < -1:  # More than 1% decrease
                    improvements.append((metric_name, change_num, change_val))
                elif change_num > 1:  # More than 1% increase
                    concerns.append((metric_name, change_num, change_val))
            else:
                # For normal metrics: positive change = improvement
                if change_num > 1:  # More than 1% increase
                    improvements.append((metric_name, change_num, change_val))
                elif change_num < -1:  # More than 1% decrease
                    concerns.append((metric_name, change_num, change_val))
        except (ValueError, TypeError):
            continue
    
    # Sort by magnitude
    improvements.sort(key=lambda x: abs(x[1]), reverse=True)
    concerns.sort(key=lambda x: abs(x[1]), reverse=True)
    
    # Take top 3
    top_improvements = improvements[:3]
    top_concerns = concerns[:3]
    
    # Build summary text
    summary_parts = []
    
    if top_improvements:
        summary_parts.append("Key Improvements:")
        for metric, _, change in top_improvements:
            summary_parts.append(f"  • {metric}: {change} QoQ")
    
    if top_concerns:
        summary_parts.append("Areas of Concern:")
        for metric, _, change in top_concerns:
            summary_parts.append(f"  • {metric}: {change} QoQ")
    
    return {
        'improvements': top_improvements,
        'concerns': top_concerns,
        'summary': '\n'.join(summary_parts) if summary_parts else 'No significant changes detected'
    }


def generate_executive_summary_from_csvs():
    """
    Generate executive summary from quarterly CSV data files.
    Pulls key metrics from newsletter and sales quarterly tables.
    
    Returns:
        str: Combined summary text for both sections (6-10 bullets total)
    """
    summary_text = []
    
    # =========================================================================
    # NEWSLETTER METRICS SUMMARY
    # =========================================================================
    summary_text.append("NEWSLETTER PERFORMANCE")
    
    # Load quarterly_table.csv for newsletter overview
    newsletter_path = os.path.join(OUTPUTS_PATH, 'general_newsletter/quarterly_table.csv')
    newsletter_df = load_csv_data(newsletter_path)
    
    if newsletter_df is not None and len(newsletter_df) >= 2:
        # Get last two quarters for comparison
        try:
            last_row = newsletter_df.iloc[-1]
            prev_row = newsletter_df.iloc[-2]
            
            # Subscribed (new subscribers)
            if 'Subscribed' in newsletter_df.columns:
                curr_subs = parse_value(last_row['Subscribed'])
                prev_subs = parse_value(prev_row['Subscribed'])
                if curr_subs and prev_subs and prev_subs != 0:
                    change_pct = ((curr_subs - prev_subs) / prev_subs) * 100
                    quality = "(favorable)" if change_pct > 0 else "(unfavorable)"
                    summary_text.append(f"  • New Subscribers: {curr_subs:,.0f} ({change_pct:+.1f}% QoQ) {quality}")
            
            # Growth Rate
            if 'Growth Rate' in newsletter_df.columns:
                curr_growth = parse_value(last_row['Growth Rate'])
                if curr_growth is not None:
                    # Check if decimal or percentage
                    if curr_growth < 1:
                        curr_growth = curr_growth * 100
                    summary_text.append(f"  • Growth Rate: {curr_growth:.2f}%")
            
            # Newsletter CVR
            if 'Newsletter CVR %' in newsletter_df.columns:
                curr_cvr = parse_value(last_row['Newsletter CVR %'])
                if curr_cvr is not None:
                    if curr_cvr < 1:
                        curr_cvr = curr_cvr * 100
                    summary_text.append(f"  • Newsletter Conversion Rate: {curr_cvr:.2f}%")
        except Exception as e:
            summary_text.append(f"  • Unable to load newsletter metrics: {e}")
    else:
        summary_text.append("  • Newsletter data not available")
    
    # Load blended engagement metrics
    blended_path = os.path.join(OUTPUTS_PATH, 'newsletter_series/09_blended_quarterly.csv')
    blended_df = load_csv_data(blended_path)
    
    if blended_df is not None and len(blended_df) >= 1:
        try:
            last_row = blended_df.iloc[-1]
            
            if 'Open Rate' in blended_df.columns:
                open_rate = parse_value(last_row['Open Rate'])
                if open_rate:
                    summary_text.append(f"  • Blended Open Rate: {open_rate:.2f}%")
            
            if 'Verified Click-Through Rate' in blended_df.columns:
                ctr = parse_value(last_row['Verified Click-Through Rate'])
                if ctr:
                    summary_text.append(f"  • Blended CTR: {ctr:.2f}%")
        except:
            pass
    
    summary_text.append("")
    
    # =========================================================================
    # SALES METRICS SUMMARY
    # =========================================================================
    summary_text.append("SALES PERFORMANCE")
    
    # Load quarterly_sales_tracker.csv
    sales_path = os.path.join(OUTPUTS_PATH, 'sales_tracker/quarterly_sales_tracker.csv')
    sales_df = load_csv_data(sales_path)
    
    if sales_df is not None and len(sales_df) >= 2:
        try:
            last_row = sales_df.iloc[-1]
            prev_row = sales_df.iloc[-2]
            
            # Live Calls
            if 'Live calls' in sales_df.columns:
                curr_calls = parse_value(last_row['Live calls'])
                prev_calls = parse_value(prev_row['Live calls'])
                if curr_calls and prev_calls and prev_calls != 0:
                    change_pct = ((curr_calls - prev_calls) / prev_calls) * 100
                    quality = "(favorable)" if change_pct > 0 else "(unfavorable)"
                    summary_text.append(f"  • Live Calls: {curr_calls:,.0f} ({change_pct:+.1f}% QoQ) {quality}")
            
            # Show Rate
            if 'Show %' in sales_df.columns:
                show_rate = parse_value(last_row['Show %'])
                if show_rate:
                    summary_text.append(f"  • Show Rate: {show_rate:.1f}%")
            
            # Offers
            if 'Offers' in sales_df.columns:
                curr_offers = parse_value(last_row['Offers'])
                prev_offers = parse_value(prev_row['Offers'])
                if curr_offers and prev_offers and prev_offers != 0:
                    change_pct = ((curr_offers - prev_offers) / prev_offers) * 100
                    quality = "(favorable)" if change_pct > 0 else "(unfavorable)"
                    summary_text.append(f"  • Offers: {curr_offers:,.0f} ({change_pct:+.1f}% QoQ) {quality}")
            
            # Closes
            if 'Close 1' in sales_df.columns:
                curr_closes = parse_value(last_row['Close 1'])
                prev_closes = parse_value(prev_row['Close 1'])
                if curr_closes and prev_closes and prev_closes != 0:
                    change_pct = ((curr_closes - prev_closes) / prev_closes) * 100
                    quality = "(favorable)" if change_pct > 0 else "(unfavorable)"
                    summary_text.append(f"  • Closes: {curr_closes:,.0f} ({change_pct:+.1f}% QoQ) {quality}")
            
            # Offer to Close Rate
            if 'Offer to Close %' in sales_df.columns:
                close_rate = parse_value(last_row['Offer to Close %'])
                if close_rate:
                    summary_text.append(f"  • Offer to Close Rate: {close_rate:.1f}%")
        except Exception as e:
            summary_text.append(f"  • Unable to load sales metrics: {e}")
    else:
        summary_text.append("  • Sales data not available")
    
    return '\n'.join(summary_text)


print("✓ Section summary generation functions loaded")
# Out:
# ✓ Section summary generation functions loaded

# %% [markdown]
# ### Section 10: Document Formatting Functions

# %%
# =============================================================================
# SECTION 10: DOCUMENT FORMATTING FUNCTIONS
# =============================================================================
# Functions for document layout, tables, and page management
# Includes color formatting for QoQ columns
# Includes source file display below tables

def add_page_break(doc):
    """
    Add a page break to the document.
    Creates a new paragraph with a page break.
    Use insert_page_break_before() when possible to avoid blank pages.
    """
    doc.add_page_break()


def insert_page_break_before(paragraph):
    """
    Insert a page break at the START of an existing paragraph.
    This prevents blank pages by attaching the break to content.
    """
    run = paragraph.runs[0] if paragraph.runs else paragraph.add_run()
    br = OxmlElement('w:br')
    br.set(qn('w:type'), 'page')
    run._r.insert(0, br)


def set_cell_shading(cell, color_hex):
    """Apply background shading to a table cell."""
    shading = parse_xml(f'<w:shd {nsdecls("w")} w:fill="{color_hex}"/>')
    cell._tc.get_or_add_tcPr().append(shading)


def add_formatted_table(doc, df, title=None, color_qoq=True, source_file=None):
    """
    Add a formatted data table to the document.
    Color codes the QoQ column based on positive/negative values.
    
    Args:
        doc: Document object
        df: DataFrame with table data
        title: Optional title above table
        color_qoq: Whether to color code the QoQ column
        source_file: Optional source file path to display below table
    """
    if title:
        p = doc.add_paragraph()
        run = p.add_run(title)
        run.bold = True
        run.font.size = Pt(14)
        p.paragraph_format.space_after = Pt(6)
    
    table = doc.add_table(rows=1, cols=len(df.columns))
    table.style = 'Table Grid'
    
    # Header row
    header_cells = table.rows[0].cells
    for i, col_name in enumerate(df.columns):
        header_cells[i].text = str(col_name)
        header_cells[i].paragraphs[0].runs[0].bold = True
        header_cells[i].paragraphs[0].runs[0].font.size = Pt(11)
        set_cell_shading(header_cells[i], "D9E2F3")
    
    # Find the QoQ column index (usually last or second-to-last)
    qoq_col_idx = None
    for i, col in enumerate(df.columns):
        col_lower = str(col).lower()
        if 'qoq' in col_lower or 'mom' in col_lower or 'wow' in col_lower or col_lower in ['qoq', 'qoq/qtd']:
            qoq_col_idx = i
            break
    
    # If not found by name, assume it's the last column with % values
    if qoq_col_idx is None:
        qoq_col_idx = len(df.columns) - 1
    
    # Data rows
    for _, row in df.iterrows():
        row_cells = table.add_row().cells
        for i, value in enumerate(row):
            cell = row_cells[i]
            cell.text = str(value) if pd.notna(value) else ""
            
            for paragraph in cell.paragraphs:
                for run in paragraph.runs:
                    run.font.size = Pt(11)
            
            # Color code QoQ column
            if color_qoq and i == qoq_col_idx:
                try:
                    val_str = str(value).replace('%', '').replace('+', '').strip()
                    val_num = float(val_str)
                    metric_name = str(row.iloc[0]).lower() if len(row) > 0 else ""
                    
                    is_inverted = any(inv.lower() in metric_name for inv in INVERTED_METRICS)
                    
                    if is_inverted:
                        # For inverted metrics: negative = good (green), positive = bad (red)
                        if val_num < 0:
                            set_cell_shading(cell, "C6EFCE")  # Green
                        elif val_num > 0:
                            set_cell_shading(cell, "FFC7CE")  # Red
                    else:
                        # For normal metrics: positive = good (green), negative = bad (red)
                        if val_num > 0:
                            set_cell_shading(cell, "C6EFCE")  # Green
                        elif val_num < 0:
                            set_cell_shading(cell, "FFC7CE")  # Red
                except (ValueError, TypeError):
                    pass
    
    # Add source file below table (dark gray, small font)
    if source_file:
        p = doc.add_paragraph()
        run = p.add_run(f"Source: {source_file}")
        run.font.size = Pt(7)
        run.font.color.rgb = RGBColor(100, 100, 100)  # Dark gray
        p.paragraph_format.space_before = Pt(2)
        p.paragraph_format.space_after = Pt(6)


def add_page_numbers(doc):
    """Add page numbers to document footer."""
    for section in doc.sections:
        footer = section.footer
        footer.is_linked_to_previous = False
        
        p = footer.paragraphs[0] if footer.paragraphs else footer.add_paragraph()
        p.alignment = WD_ALIGN_PARAGRAPH.CENTER
        
        run1 = p.add_run("Page ")
        run1.font.size = Pt(10)
        
        fldChar1 = OxmlElement('w:fldChar')
        fldChar1.set(qn('w:fldCharType'), 'begin')
        instrText1 = OxmlElement('w:instrText')
        instrText1.text = "PAGE"
        fldChar2 = OxmlElement('w:fldChar')
        fldChar2.set(qn('w:fldCharType'), 'separate')
        fldChar3 = OxmlElement('w:fldChar')
        fldChar3.set(qn('w:fldCharType'), 'end')
        
        run2 = p.add_run()
        run2._r.append(fldChar1)
        run2._r.append(instrText1)
        run2._r.append(fldChar2)
        run2._r.append(fldChar3)
        run2.font.size = Pt(10)
        
        run3 = p.add_run(" of ")
        run3.font.size = Pt(10)
        
        fldChar4 = OxmlElement('w:fldChar')
        fldChar4.set(qn('w:fldCharType'), 'begin')
        instrText2 = OxmlElement('w:instrText')
        instrText2.text = "NUMPAGES"
        fldChar5 = OxmlElement('w:fldChar')
        fldChar5.set(qn('w:fldCharType'), 'separate')
        fldChar6 = OxmlElement('w:fldChar')
        fldChar6.set(qn('w:fldCharType'), 'end')
        
        run4 = p.add_run()
        run4._r.append(fldChar4)
        run4._r.append(instrText2)
        run4._r.append(fldChar5)
        run4._r.append(fldChar6)
        run4.font.size = Pt(10)


print("✓ Document formatting functions loaded")
# Out:
# ✓ Document formatting functions loaded

# %% [markdown]
# ### Section 11: Chart with Insights Function

# %%
# =============================================================================
# SECTION 11: CHART WITH INSIGHTS FUNCTION
# =============================================================================
# Adds chart image and insights to the document
# Charts are sized to fit 2 per page with their insights
# Includes full source paths for both chart image and data CSV

def add_chart_with_insights(doc, chart_name, config, source_log, page_break_before=False):
    """
    Add a chart image with auto-generated insights to the document.
    Chart + insights are kept compact to fit 2 per page.
    
    Includes:
    - Chart source path (e.g., visualizations/newsletter_quarterly/quarterly_visits.png)
    - Data source path (e.g., outputs/newsletter/quarterly_newsletter.csv)
    """
    # Chart title
    p = doc.add_paragraph()
    run = p.add_run(chart_name)
    run.bold = True
    run.font.size = Pt(12)
    p.paragraph_format.space_before = Pt(10)
    p.paragraph_format.space_after = Pt(3)
    
    if page_break_before:
        insert_page_break_before(p)
    
    # Chart image - smaller size
    image_path = os.path.join(VISUALIZATIONS_PATH, config['image'])
    
    if os.path.exists(image_path):
        pic = doc.add_picture(image_path, width=Inches(CONFIG['chart_width_inches']))
        # Reduce space after image
        last_para = doc.paragraphs[-1]
        last_para.paragraph_format.space_after = Pt(1)
        source_log.append(f"  Chart: {config['image']}")
    else:
        doc.add_paragraph(f"[Chart not found: {config['image']}]")
        source_log.append(f"  Chart: {config['image']} (NOT FOUND)")
    
    # Add full source paths below chart (dark gray, small font)
    # Chart source: visualizations/[folder]/[file].png
    # Data source: outputs/[folder]/[file].csv
    chart_source = f"visualizations/{config['image']}"
    data_source = f"outputs/{config['csv']}"
    
    p = doc.add_paragraph()
    # Chart source
    run = p.add_run(f"Chart: {chart_source}\n")
    run.font.size = Pt(7)
    run.font.color.rgb = RGBColor(100, 100, 100)  # Dark gray
    # Data source
    run = p.add_run(f"Source: {data_source}")
    run.font.size = Pt(7)
    run.font.color.rgb = RGBColor(100, 100, 100)  # Dark gray
    p.paragraph_format.space_before = Pt(0)
    p.paragraph_format.space_after = Pt(2)
    
    # Generate insights
    insights = get_chart_data_insights(chart_name, config)
    insight_text = generate_chart_insight_text(insights, config['metric'])
    
    # Insight label
    p = doc.add_paragraph()
    run = p.add_run("Insights:")
    run.bold = True
    run.font.size = Pt(9)
    p.paragraph_format.space_before = Pt(2)
    p.paragraph_format.space_after = Pt(1)
    
    # Insight text - compact
    p = doc.add_paragraph(insight_text)
    p.paragraph_format.left_indent = Inches(0.15)
    p.paragraph_format.space_after = Pt(8)
    for run in p.runs:
        run.font.size = Pt(9)
    
    source_log.append(f"  Data: {config['csv']} → {config['metric']}")
    
    return True


print("✓ Chart with insights function loaded")
# Out:
# ✓ Chart with insights function loaded

# %% [markdown]
# ### Section 12: Cover Page and Executive Summary

# %%
# =============================================================================
# SECTION 12: COVER PAGE AND EXECUTIVE SUMMARY
# =============================================================================
# Creates the report cover page with title, dates, and table of contents
# Creates executive summary on page 2

def add_table_of_contents(doc):
    """
    Add a Table of Contents field to the document.
    User must right-click and 'Update Field' in Word to populate.
    """
    paragraph = doc.add_paragraph()
    run = paragraph.add_run()
    
    fldChar1 = OxmlElement('w:fldChar')
    fldChar1.set(qn('w:fldCharType'), 'begin')
    
    instrText = OxmlElement('w:instrText')
    instrText.set(qn('xml:space'), 'preserve')
    instrText.text = ' TOC \\o "1-3" \\h \\z \\u '
    
    fldChar2 = OxmlElement('w:fldChar')
    fldChar2.set(qn('w:fldCharType'), 'separate')
    
    fldChar3 = OxmlElement('w:fldChar')
    fldChar3.set(qn('w:fldCharType'), 'end')
    
    run._r.append(fldChar1)
    run._r.append(instrText)
    run._r.append(fldChar2)
    
    placeholder_run = paragraph.add_run("Right-click and select 'Update Field' to generate Table of Contents")
    placeholder_run.italic = True
    placeholder_run.font.color.rgb = RGBColor(128, 128, 128)
    
    run2 = paragraph.add_run()
    run2._r.append(fldChar3)
    
    return doc


def create_cover_page(doc, date_info):
    """
    Create cover page with title, reporting quarter dates, and table of contents.
    """
    # Title - Quarterly Business Review (QBR)
    title = doc.add_paragraph()
    title.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run = title.add_run("Quarterly Business Review (QBR)")
    run.bold = True
    run.font.size = Pt(28)
    
    doc.add_paragraph()
    
    # Reporting quarter
    subtitle = doc.add_paragraph()
    subtitle.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run = subtitle.add_run(f"Reporting Quarter: {date_info['date_range_display']}")
    run.font.size = Pt(16)
    
    doc.add_paragraph()
    
    # Generation timestamp
    gen_date = doc.add_paragraph()
    gen_date.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run = gen_date.add_run(f"Report Generated: {datetime.now().strftime('%B %d, %Y at %I:%M %p')}")
    run.font.size = Pt(11)
    run.italic = True
    
    doc.add_paragraph()
    doc.add_paragraph()
    
    # Table of Contents header
    toc_header = doc.add_paragraph()
    run = toc_header.add_run("Table of Contents")
    run.bold = True
    run.font.size = Pt(14)
    
    # Add TOC field
    add_table_of_contents(doc)
    
    return doc


def create_executive_summary(doc, date_info):
    """
    Create Executive Summary on page 2 with key improvements and concerns.
    Pulls data directly from quarterly CSV files.
    """
    add_page_break(doc)
    
    doc.add_heading("Executive Summary", level=1)
    
    # Generate summary from quarterly CSV data
    exec_summary = generate_executive_summary_from_csvs()
    
    for line in exec_summary.split('\n'):
        if line.strip():
            p = doc.add_paragraph(line)
            p.paragraph_format.space_after = Pt(3)
            # Bold section headers
            if line.isupper() or (line.endswith(':') and not line.startswith(' ')):
                for run in p.runs:
                    run.bold = True
    
    return doc


print("✓ Cover page and executive summary functions loaded")
# Out:
# ✓ Cover page and executive summary functions loaded

# %% [markdown]
# ### Section 13: Newsletter Section Generation

# %%
# =============================================================================
# SECTION 13: NEWSLETTER SECTION GENERATION
# =============================================================================
# Creates the Newsletter Metrics section with:
# - Landing Page Funnel (Pages 4-5)
# - Engagement (Pages 6-7)
# - Growth & Churn (Pages 8-9)
#
# Note: Newsletter Series Performance pages removed per specification
#
# Section title uses Heading 1 style so it appears in Table of Contents
#
# UPDATED: Reduced spacing above section titles (from 10 spacers to 5)

def add_section_title(doc, title_text, page_break_before=True):
    """
    Add a centered section title as Heading 1 (appears in Table of Contents).
    Used for main section headers (Section 1, Section 2).
    
    Creates a title that appears in the UPPER-CENTER of the page.
    Uses Heading 1 style so it's included in the Table of Contents.
    
    UPDATED: Reduced vertical spacing - title now at ~40% from top instead of 50%
    """
    if page_break_before:
        doc.add_page_break()
    
    # Add fewer spacer paragraphs to position title higher on page
    # Changed from 10 spacers to 5 spacers (approximately 40% from top)
    for _ in range(5):
        spacer = doc.add_paragraph()
        spacer.paragraph_format.space_before = Pt(0)
        spacer.paragraph_format.space_after = Pt(40)
    
    # Add the section title as Heading 1 (for TOC) - centered
    h = doc.add_heading(title_text, level=1)
    h.alignment = WD_ALIGN_PARAGRAPH.CENTER
    
    # Style the heading
    for run in h.runs:
        run.bold = True
        run.font.size = Pt(28)
        run.font.color.rgb = RGBColor(31, 73, 125)  # Dark blue color
    
    h.paragraph_format.space_before = Pt(0)
    h.paragraph_format.space_after = Pt(0)
    
    return h


def create_newsletter_section(doc, source_log):
    """Create Newsletter Metrics section with all charts and insights."""
    
    # Section 1 header - CENTERED, as Heading 1 (appears in TOC)
    add_section_title(doc, "Section 1: Newsletter Metrics", page_break_before=True)
    
    # =========================================================================
    # LANDING PAGE FUNNEL (Pages 4-5)
    # =========================================================================
    h = doc.add_heading("Landing Page Funnel", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Landing Page Funnel Charts ---")
    
    # Page 4: Newsletter Visits, Visit Duration
    add_chart_with_insights(doc, 'Newsletter Visits', CHART_CONFIG['Newsletter Visits'], source_log)
    add_chart_with_insights(doc, 'Newsletter Visit Duration', CHART_CONFIG['Newsletter Visit Duration'], source_log)
    
    # Page 5: Bounce Rate, CVR %
    add_chart_with_insights(doc, 'Newsletter Bounce Rate', CHART_CONFIG['Newsletter Bounce Rate'], source_log, page_break_before=True)
    add_chart_with_insights(doc, 'Newsletter CVR %', CHART_CONFIG['Newsletter CVR %'], source_log)
    
    # =========================================================================
    # ENGAGEMENT METRICS (Pages 6-7)
    # =========================================================================
    h = doc.add_heading("Engagement Metrics", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Engagement Charts ---")
    
    # Page 6: Blended Open Rate, Blended Verified CTR
    add_chart_with_insights(doc, 'Blended Open Rate', CHART_CONFIG['Blended Open Rate'], source_log)
    add_chart_with_insights(doc, 'Blended Verified Click-Through Rate', CHART_CONFIG['Blended Verified Click-Through Rate'], source_log)
    
    # Page 7: Blended Unsub Rate
    add_chart_with_insights(doc, 'Blended Unsub Rate', CHART_CONFIG['Blended Unsub Rate'], source_log, page_break_before=True)
    
    # =========================================================================
    # GROWTH & CHURN (Pages 8-9)
    # =========================================================================
    h = doc.add_heading("Growth & Churn", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Growth & Churn Charts ---")
    
    # Page 8: Growth Rate, New Subscribers
    add_chart_with_insights(doc, 'Growth Rate', CHART_CONFIG['Growth Rate'], source_log)
    add_chart_with_insights(doc, 'New Subscribers', CHART_CONFIG['New Subscribers'], source_log)
    
    # Page 9: Unsubscribes, Leak Rate
    add_chart_with_insights(doc, 'Unsubscribes', CHART_CONFIG['Unsubscribes'], source_log, page_break_before=True)
    add_chart_with_insights(doc, 'Leak Rate', CHART_CONFIG['Leak Rate'], source_log)
    
    return doc


print("✓ Newsletter section function loaded")
# Out:
# ✓ Newsletter section function loaded

# %% [markdown]
# ### Section 14: Sales Section Generation

# %%
# =============================================================================
# SECTION 14: SALES SECTION GENERATION
# =============================================================================
# Creates the Sales Metrics section with:
# - Lead Time & Deal Upgrade (Pages 13-14)
# - Pro Site Funnel (Page 15)
# - Booked Calls (Page 16)
# - Sales Pipeline: Calls (Pages 17-18)
# - Offers (Page 19)
# - Closes (Page 20)
#
# Section title uses Heading 1 style so it appears in Table of Contents

def create_sales_section(doc, source_log):
    """Create Sales Metrics section with all charts and insights."""
    
    # Section 2 header - CENTERED, as Heading 1 (appears in TOC)
    add_section_title(doc, "Section 2: Sales Metrics", page_break_before=True)
    
    # =========================================================================
    # LEAD TIME & DEAL UPGRADE (Pages 13-14)
    # =========================================================================
    h = doc.add_heading("Lead Time & Deal Upgrade", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Lead Time & Deal Upgrade ---")
    
    # Page 13: Average Lead Time
    add_chart_with_insights(doc, 'Average Lead Time', CHART_CONFIG['Average Lead Time'], source_log)
    
    # Page 14: Deal Upgrade Visits, Deal Upgrade CVR
    add_chart_with_insights(doc, 'Deal Upgrade Visits', CHART_CONFIG['Deal Upgrade Visits'], source_log, page_break_before=True)
    add_chart_with_insights(doc, 'Deal Upgrade CVR', CHART_CONFIG['Deal Upgrade CVR'], source_log)
    
    # =========================================================================
    # PRO SITE FUNNEL (Page 15)
    # =========================================================================
    h = doc.add_heading("Pro Site Funnel", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Pro Site ---")
    
    # Page 15: Pro Site Visits, Pro Site CVR
    add_chart_with_insights(doc, 'Pro Site Visits', CHART_CONFIG['Pro Site Visits'], source_log)
    add_chart_with_insights(doc, 'Pro Site CVR', CHART_CONFIG['Pro Site CVR'], source_log)
    
    # =========================================================================
    # BOOKED CALLS (Page 16)
    # =========================================================================
    h = doc.add_heading("Booked Calls", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Booked Calls ---")
    
    # Page 16: Booked Calls - Closers, Booked Calls - Setters
    add_chart_with_insights(doc, 'Booked Calls - Closers (Discovery Call)', CHART_CONFIG['Booked Calls - Closers (Discovery Call)'], source_log)
    add_chart_with_insights(doc, 'Booked Calls - Setters (Intro Call)', CHART_CONFIG['Booked Calls - Setters (Intro Call)'], source_log)
    
    # =========================================================================
    # SALES PIPELINE: CALLS (Pages 17-18)
    # =========================================================================
    h = doc.add_heading("Sales Pipeline: Calls", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Sales Pipeline Calls ---")
    
    # Page 17: Scheduled Calls, Live Calls
    add_chart_with_insights(doc, 'Scheduled Calls', CHART_CONFIG['Scheduled Calls'], source_log)
    add_chart_with_insights(doc, 'Live Calls', CHART_CONFIG['Live Calls'], source_log)
    
    # Page 18: Show Rate
    add_chart_with_insights(doc, 'Show Rate', CHART_CONFIG['Show Rate'], source_log, page_break_before=True)
    
    # =========================================================================
    # OFFERS (Page 19)
    # =========================================================================
    h = doc.add_heading("Offers", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Offers ---")
    
    # Page 19: Offers, Offer Rate
    add_chart_with_insights(doc, 'Offers', CHART_CONFIG['Offers'], source_log)
    add_chart_with_insights(doc, 'Offer Rate', CHART_CONFIG['Offer Rate'], source_log)
    
    # =========================================================================
    # CLOSES (Page 20)
    # =========================================================================
    h = doc.add_heading("Closes", level=2)
    insert_page_break_before(h)
    source_log.append(f"\n--- Closes ---")
    
    # Page 20: Closes, Offer to Close Rate
    add_chart_with_insights(doc, 'Closes', CHART_CONFIG['Closes'], source_log)
    add_chart_with_insights(doc, 'Offer to Close Rate', CHART_CONFIG['Offer to Close Rate'], source_log)
    
    return doc


print("✓ Sales section function loaded")
# Out:
# ✓ Sales section function loaded

# %% [markdown]
# ### Section 15: Main Report Generation Function

# %%
# =============================================================================
# SECTION 15: MAIN REPORT GENERATION
# =============================================================================
# Orchestrates the complete QBR report generation process
# Sets the reporting quarter filter before processing any data

def generate_qbr_report():
    """
    Generate the complete Quarterly Business Review report.
    
    Process:
    1. Load reference dates from analysis_ref_date.csv (Quarter Start/End)
    2. Set reporting quarter end date for data filtering
    3. Create document with cover page
    4. Add executive summary
    5. Add newsletter section (charts + insights)
    6. Add sales section (charts + insights)
    7. Add page numbers
    8. Save DOCX to reports folder
    
    Output:
    - Quarterly_Business_Review_<date_range>.docx
    - Prints source log showing all files used
    """
    print("=" * 60)
    print("GENERATING QUARTERLY BUSINESS REVIEW (QBR) REPORT")
    print("=" * 60)
    
    source_log = []
    source_log.append("\n" + "=" * 60)
    source_log.append("DATA SOURCES USED IN THIS REPORT")
    source_log.append("=" * 60)
    
    # =========================================================================
    # Step 1: Load reference dates (using Quarter Start/End for QBR)
    # =========================================================================
    print("\n[Step 1] Loading reference dates...")
    date_info = parse_reference_dates(REF_DATE_FILE)
    if date_info is None:
        print("  ⚠ Could not load reference dates. Using default values.")
        date_info = {
            'quarter_start': 'Unknown',
            'quarter_end': 'Unknown',
            'date_range_filename': 'unknown_date',
            'date_range_display': 'Unknown Date Range'
        }
    print(f"  Reporting quarter: {date_info['date_range_display']}")
    source_log.append(f"\nReference Date File: analysis_ref_date.csv")
    source_log.append(f"  Reporting quarter: {date_info['date_range_display']}")
    
    # =========================================================================
    # Step 2: Set reporting quarter end date for filtering
    # This ensures only data up to the quarter end date is included
    # =========================================================================
    print("\n[Step 2] Setting data filter...")
    set_reporting_quarter_end(date_info)
    
    # =========================================================================
    # Step 3: Create document
    # =========================================================================
    print("\n[Step 3] Creating document...")
    doc = Document()
    
    # =========================================================================
    # Step 4: Cover page with title, dates, and table of contents
    # =========================================================================
    print("\n[Step 4] Adding cover page...")
    doc = create_cover_page(doc, date_info)
    
    # =========================================================================
    # Step 5: Executive Summary - auto-generated from quarterly CSV data
    # Pulls key metrics from:
    # - general_newsletter/quarterly_table.csv
    # - newsletter_series/09_blended_quarterly.csv
    # - sales_tracker/quarterly_sales_tracker.csv
    # =========================================================================
    print("\n[Step 5] Adding executive summary...")
    doc = create_executive_summary(doc, date_info)
    
    # =========================================================================
    # Step 6: Newsletter section with charts and auto-generated insights
    # Includes: Landing Page Funnel, Engagement, Growth & Churn
    # =========================================================================
    print("\n[Step 6] Adding newsletter section...")
    doc = create_newsletter_section(doc, source_log)
    
    # =========================================================================
    # Step 7: Sales section with charts and auto-generated insights
    # Includes: Lead Time & Deal Upgrade, Pro Site, Booked Calls,
    #           Sales Pipeline, Offers, Closes
    # =========================================================================
    print("\n[Step 7] Adding sales section...")
    doc = create_sales_section(doc, source_log)
    
    # =========================================================================
    # Step 8: Add page numbers to footer
    # =========================================================================
    print("\n[Step 8] Adding page numbers...")
    add_page_numbers(doc)
    
    # =========================================================================
    # Step 9: Save document to reports folder
    # Filename format: Quarterly_Business_Review_<start>_to_<end>.docx
    # =========================================================================
    print("\n[Step 9] Saving document...")
    filename = f"Quarterly_Business_Review_{date_info['date_range_filename']}.docx"
    filepath = os.path.join(REPORTS_PATH, filename)
    doc.save(filepath)
    
    print(f"\n{'=' * 60}")
    print("✓ REPORT GENERATED SUCCESSFULLY!")
    print("=" * 60)
    print(f"  File: {filename}")
    print(f"  Location: {filepath}")
    
    # =========================================================================
    # Print source log - shows all files used for data and charts
    # This helps verify correct files are being pulled
    # =========================================================================
    print("\n")
    for line in source_log:
        print(line)
    
    return filepath


print("✓ Main report generation function loaded")
# Out:
# ✓ Main report generation function loaded

# %% [markdown]
# ### Section 16: Execute Report Generation

# %%
# =============================================================================
# SECTION 16: EXECUTE REPORT GENERATION
# =============================================================================
# Run this cell to generate the Quarterly Business Review report
#
# Output:
# - DOCX file saved to 'reports' folder
# - Source log printed showing all data files and charts used
#
# After running:
# 1. Open the DOCX file in Microsoft Word
# 2. Right-click the Table of Contents and select "Update Field"
# 3. Review and add any manual notes as needed

# Generate the report
report_path = generate_qbr_report()

print(f"\n\n{'=' * 60}")
print("REPORT COMPLETE!")
print("=" * 60)
print(f"Open: {report_path}")
# Out:
# ============================================================
# GENERATING QUARTERLY BUSINESS REVIEW (QBR) REPORT
# ============================================================
#
# [Step 1] Loading reference dates...
#   Reporting quarter: 01/01/2024 to 12/31/2025
#
# [Step 2] Setting data filter...
#   Data filter: Only including data up to 12/31/2025
#
# [Step 3] Creating document...
#
# [Step 4] Adding cover page...
#
# [Step 5] Adding executive summary...
#
# [Step 6] Adding newsletter section...
#
# [Step 7] Adding sales section...
#
# [Step 8] Adding page numbers...
#
# [Step 9] Saving document...
#
# ============================================================
# ✓ REPORT GENERATED SUCCESSFULLY!
# ============================================================
#   File: Quarterly_Business_Review_01-01-2024_to_12-31-2025.docx
#   Location: /Users/mariaangelicabaldres/Desktop/smb_dh_metrics/reports/Quarterly_Business_Review_01-01-2024_to_12-31-2025.docx
#
#
#
# ============================================================
# DATA SOURCES USED IN THIS REPORT
# ============================================================
#
# Reference Date File: analysis_ref_date.csv
#   Reporting quarter: 01/01/2024 to 12/31/2025
#
# --- Landing Page Funnel Charts ---
#   Chart: newsletter_quarterly/quarterly_visits.png
#   Data: newsletter/quarterly_newsletter.csv → Visits
#   Chart: newsletter_quarterly/quarterly_avg_duration.png
#   Data: newsletter/quarterly_newsletter.csv → Avg Duration
#   Chart: newsletter_quarterly/quarterly_bounce_rate.png
#   Data: newsletter/quarterly_newsletter.csv → Bounce Rate
#   Chart: general_newsletter_quarterly/quarterly_newsletter_cvr.png
#   Data: general_newsletter/quarterly_table.csv → Newsletter CVR %
#
# --- Engagement Charts ---
#   Chart: newsletter_series_quarterly/blended_open_rate.png
#   Data: newsletter_series/09_blended_quarterly.csv → Open Rate
#   Chart: newsletter_series_quarterly/blended_verified_ctr.png
#   Data: newsletter_series/09_blended_quarterly.csv → Verified Click-Through Rate
#   Chart: newsletter_series_quarterly/blended_unsubscribe_rate.png
#   Data: newsletter_series/09_blended_quarterly.csv → Unsubscribe Rate
#
# --- Growth & Churn Charts ---
#   Chart: general_newsletter_quarterly/quarterly_growth_rate.png
#   Data: general_newsletter/quarterly_table.csv → Growth Rate
#   Chart: general_newsletter_quarterly/quarterly_subscribed.png
#   Data: general_newsletter/quarterly_table.csv → Subscribed
#   Chart: general_newsletter_quarterly/quarterly_unsubscribed.png
#   Data: general_newsletter/quarterly_table.csv → Unsubscribed
#   Chart: general_newsletter_quarterly/quarterly_leak_rate.png
#   Data: general_newsletter/quarterly_table.csv → Leak Rate
#
# --- Lead Time & Deal Upgrade ---
#   Chart: discovery_intro_blended_quarterly/quarterly_avg_lead_time_completed.png
#   Data: discovery_intro/quarterly_discovery_intro_blended.csv → Avg Lead Time (Days)(Completed)
#   Chart: deal_upgrade_quarterly/quarterly_visits.png
#   Data: deal_upgrade/quarterly_deal_upgrade.csv → Visits
#   Chart: deal_upgrade_quarterly/quarterly_conversion_rate.png
#   Data: deal_upgrade/quarterly_deal_upgrade.csv → Conversion Rate
#
# --- Pro Site ---
#   Chart: pro_site_quarterly/quarterly_visits.png
#   Data: pro_site/quarterly_pro_site.csv → Visits
#   Chart: pro_site_quarterly/quarterly_conversion_rate.png
#   Data: pro_site/quarterly_pro_site.csv → Conversion Rate
#
# --- Booked Calls ---
#   Chart: discovery_call_quarterly/quarterly_booked_calls_completed.png
#   Data: discovery_intro/quarterly_discovery_call.csv → Booked Calls (Completed)
#   Chart: intro_call_quarterly/quarterly_booked_calls_completed.png
#   Data: discovery_intro/quarterly_intro_call.csv → Booked Calls (Completed)
#
# --- Sales Pipeline Calls ---
#   Chart: sales_tracker_quarterly/quarterly_sched_calls.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Sched. calls
#   Chart: sales_tracker_quarterly/quarterly_live_calls.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Live calls
#   Chart: sales_tracker_quarterly/quarterly_show_pct.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Show %
#
# --- Offers ---
#   Chart: sales_tracker_quarterly/quarterly_offers.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Offers
#   Chart: sales_tracker_quarterly/quarterly_offer_pct.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Offer %
#
# --- Closes ---
#   Chart: sales_tracker_quarterly/quarterly_close_1.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Close 1
#   Chart: sales_tracker_quarterly/quarterly_offer_to_close_pct.png
#   Data: sales_tracker/quarterly_sales_tracker.csv → Offer to Close %
#
#
# ============================================================
# REPORT COMPLETE!
# ============================================================
# Open: /Users/mariaangelicabaldres/Desktop/smb_dh_metrics/reports/Quarterly_Business_Review_01-01-2024_to_12-31-2025.docx
